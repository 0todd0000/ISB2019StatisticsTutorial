# %% [markdown]
# # Example notebook
#
# HTML comments and images along with interactive Python or Matlab!

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ### Example Python code

# %%
import numpy as np
from matplotlib import pyplot

pyplot.figure()
x = np.random.randn(10)
pyplot.plot( x )
pyplot.show()
